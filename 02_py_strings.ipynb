# %% [markdown]
# ## 02_py_strings

# %% [markdown]
# This notebook will cover general string manipulation in python.

# %% [markdown]
# Topics covered:
#
# **1. Basic string manipulation**
# * combine strings
# * extract characters from strings
# * string lengths
#
# **2. Remove string patterns**
# * remove strings
# * remove whitespace
#
# **3. String detection**
# * detect pattern
# * using patterns create columns and filter data
#
# **Glossary**

# %%
# Set up

# pandas and numpy are universally used in python, like tidyverse is in R. 
import pandas as pd
import numpy as np

# !pip install openpyxl

# chnage from scientific notation 
pd.set_option('display.float_format', lambda x: '%.5f' % x)

trade = pd.read_excel("data/trade_data.xlsx") # upload xlsxl
tariff = pd.read_excel("data/tariff_data.xlsx")
uk_trqs = pd.read_csv("data/uk_trqs.csv",dtype={'quota__order_number': str})

trade.columns = trade.columns.str.lower().str.replace(" ","_")
uk_trqs.columns = uk_trqs.columns.str.lower().str.replace(" ","_")
# Out:
# Looking in indexes: https://s3-eu-west-2.amazonaws.com/mirrors.notebook.uktrade.io/pypi/
# Collecting openpyxl
#   Downloading https://s3-eu-west-2.amazonaws.com/mirrors.notebook.uktrade.io/pypi/openpyxl/openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 80.0 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading https://s3-eu-west-2.amazonaws.com/mirrors.notebook.uktrade.io/pypi/et-xmlfile/et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# ****

# %% [markdown]
# ### 1. Basic string manipulation

# %% [markdown]
# for simple string manioulation we will use the trade dataset.

# %%
trade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41142 entries, 0 to 41141
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               41142 non-null  int64
#  1   flow               41142 non-null  object
#  2   commodity_code     41142 non-null  object
#  3   country_code       41142 non-null  object
#  4   country_name       41142 non-null  object
#  5   value_gbp          41142 non-null  int64
#  6   suppression_notes  0 non-null      float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.2+ MB

# %%
trade
# Out:
#        year     flow commodity_code country_code country_name  value_gbp  \
# 0      2020  Exports       01012100           TW       Taiwan        892
# 1      2020  Exports       01062000           TW       Taiwan      14101
# 2      2020  Exports       01063100           TW       Taiwan       1750
# 3      2020  Exports       02031913           TW       Taiwan     290818
# 4      2020  Exports       02031990           TW       Taiwan       1140
# ...     ...      ...            ...          ...          ...        ...
# 41137  2019  Imports       94036090           ZM       Zambia        932
# 41138  2020  Imports       95030041           ZM       Zambia       3812
# 41139  2020  Imports       95030099           ZM       Zambia       3972
# 41140  2020  Imports       97050000           ZM       Zambia       2213
# 41141  2020  Imports       99209900           ZM       Zambia      25009
#
#        suppression_notes
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 41137                NaN
# 41138                NaN
# 41139                NaN
# 41140                NaN
# 41141                NaN
#
# [41142 rows x 7 columns]

# %%
# combine strings of country_code and country_name

df = trade.copy()
df["combined_col"] = df["country_code"]+df["country_name"]
df["combined_col2"] = df["country_code"]+"_"+df["country_name"]
df.head()
# Out:
#    year     flow commodity_code country_code country_name  value_gbp  \
# 0  2020  Exports       01012100           TW       Taiwan        892
# 1  2020  Exports       01062000           TW       Taiwan      14101
# 2  2020  Exports       01063100           TW       Taiwan       1750
# 3  2020  Exports       02031913           TW       Taiwan     290818
# 4  2020  Exports       02031990           TW       Taiwan       1140
#
#    suppression_notes combined_col combined_col2
# 0                NaN     TWTaiwan     TW_Taiwan
# 1                NaN     TWTaiwan     TW_Taiwan
# 2                NaN     TWTaiwan     TW_Taiwan
# 3                NaN     TWTaiwan     TW_Taiwan
# 4                NaN     TWTaiwan     TW_Taiwan

# %%
# combine year (numerical column) and flow (string)
# note you can't combine the numerical value directly so have to convert to string
# this can simply be done using map(str). 

df = trade.copy()
df["combined_col"] = df["year"].map(str) + df["flow"]
df.head()

# note try running code without map(str) to error check.
# Out:
#    year     flow commodity_code country_code country_name  value_gbp  \
# 0  2020  Exports       01012100           TW       Taiwan        892
# 1  2020  Exports       01062000           TW       Taiwan      14101
# 2  2020  Exports       01063100           TW       Taiwan       1750
# 3  2020  Exports       02031913           TW       Taiwan     290818
# 4  2020  Exports       02031990           TW       Taiwan       1140
#
#    suppression_notes combined_col
# 0                NaN  2020Exports
# 1                NaN  2020Exports
# 2                NaN  2020Exports
# 3                NaN  2020Exports
# 4                NaN  2020Exports

# %% [markdown]
# #### Extract strings

# %%
# extract substring
# example from the commodity code column which is an 8-digt format. Extract HS2,4 and 6 formats. 
# equiv. of using LEFT in excel.
# str.slice

df = trade.copy()
df["hs2"] = df["commodity_code"].str.slice(0,2) # index 0 for start of string. 
df["hs4"] = df["commodity_code"].str.slice(0,4)
df["hs6"] = df["commodity_code"].str.slice(0,6)
df.head()
# Out:
#    year     flow commodity_code country_code country_name  value_gbp  \
# 0  2020  Exports       01012100           TW       Taiwan        892
# 1  2020  Exports       01062000           TW       Taiwan      14101
# 2  2020  Exports       01063100           TW       Taiwan       1750
# 3  2020  Exports       02031913           TW       Taiwan     290818
# 4  2020  Exports       02031990           TW       Taiwan       1140
#
#    suppression_notes hs2   hs4     hs6
# 0                NaN  01  0101  010121
# 1                NaN  01  0106  010620
# 2                NaN  01  0106  010631
# 3                NaN  02  0203  020319
# 4                NaN  02  0203  020319

# %%
# RIGHT example 

df["right"] = df["commodity_code"].str[-2:] # n last 2 digits
df["right2"] = df["commodity_code"].str[-4:] # n last 4 digits etc. 

#alternative way of performing LEFT equiv. 
df["left"] = df["commodity_code"].str[:2]
df["left2"] = df["commodity_code"].str[:4]
df["left2"] = df["commodity_code"].str[:6]
df

# MID example
df["mid"] = df["commodity_code"].str.slice(2,6) # middle for digits. i.e. start at 2 (3 string including 0 index) up to the 6th string

df
# Out:
#        year     flow commodity_code country_code country_name  value_gbp  \
# 0      2020  Exports       01012100           TW       Taiwan        892
# 1      2020  Exports       01062000           TW       Taiwan      14101
# 2      2020  Exports       01063100           TW       Taiwan       1750
# 3      2020  Exports       02031913           TW       Taiwan     290818
# 4      2020  Exports       02031990           TW       Taiwan       1140
# ...     ...      ...            ...          ...          ...        ...
# 41137  2019  Imports       94036090           ZM       Zambia        932
# 41138  2020  Imports       95030041           ZM       Zambia       3812
# 41139  2020  Imports       95030099           ZM       Zambia       3972
# 41140  2020  Imports       97050000           ZM       Zambia       2213
# 41141  2020  Imports       99209900           ZM       Zambia      25009
#
#        suppression_notes hs2   hs4     hs6 right right2 left   left2   mid
# 0                    NaN  01  0101  010121    00   2100   01  010121  0121
# 1                    NaN  01  0106  010620    00   2000   01  010620  0620
# 2                    NaN  01  0106  010631    00   3100   01  010631  0631
# 3                    NaN  02  0203  020319    13   1913   02  020319  0319
# 4                    NaN  02  0203  020319    90   1990   02  020319  0319
# ...                  ...  ..   ...     ...   ...    ...  ...     ...   ...
# 41137                NaN  94  9403  940360    90   6090   94  940360  0360
# 41138                NaN  95  9503  950300    41   0041   95  950300  0300
# 41139                NaN  95  9503  950300    99   0099   95  950300  0300
# 41140                NaN  97  9705  970500    00   0000   97  970500  0500
# 41141                NaN  99  9920  992099    00   9900   99  992099  2099
#
# [41142 rows x 15 columns]

# %% [markdown]
# #### String length

# %%
# use str.len

df = trade.copy()
df["length"] = df["commodity_code"].str.len()
df.head(3)
# Out:
#    year     flow commodity_code country_code country_name  value_gbp  \
# 0  2020  Exports       01012100           TW       Taiwan        892
# 1  2020  Exports       01062000           TW       Taiwan      14101
# 2  2020  Exports       01063100           TW       Taiwan       1750
#
#    suppression_notes  length
# 0                NaN       8
# 1                NaN       8
# 2                NaN       8

# %%
# NOTE. YOu can;'t directly use str.len for numerical values. 
# you can convert the numerical value to string combininging with apply:

df["year_len"] = df["year"].map(str).apply(len)
df.head(2)
# Out:
#    year     flow commodity_code country_code country_name  value_gbp  \
# 0  2020  Exports       01012100           TW       Taiwan        892
# 1  2020  Exports       01062000           TW       Taiwan      14101
#
#    suppression_notes  length  year_len
# 0                NaN       8         4
# 1                NaN       8         4

# %% [markdown]
# ### 2. Remove string patterns

# %%
# UK TRQ data found here: https://data.gov.uk/dataset/4a478c7e-16c7-4c28-ab9b-967bb79342e9/uk-trade-quotas
# str.replace remove "|" from quota commodities
df = uk_trqs.copy()
df.head(2)
# Out:
#    quota_definition__sid quota__order_number quota__geographical_areas  \
# 0                  20815               50006                ERGA OMNES
# 1                  20814               50006                ERGA OMNES
#
#                                      quota__headings  \
# 0  0302 – Fish, fresh or chilled, excluding fish ...
# 1  0302 – Fish, fresh or chilled, excluding fish ...
#
#                                   quota__commodities quota__measurement_unit  \
# 0  0302410000|0303510000|0304595000|0304599010|03...           Kilogram (kg)
# 1  0302410000|0303510000|0304595000|0304599010|03...           Kilogram (kg)
#
#    quota__monetary_unit  quota_definition__description  \
# 0                   NaN                            NaN
# 1                   NaN                            NaN
#
#   quota_definition__validity_start_date quota_definition__validity_end_date  \
# 0                            01/01/2021                          14/02/2021
# 1                            16/06/2021                          14/02/2022
#
#   quota_definition__suspension_periods  quota_definition__blocking_periods  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
#
#   quota_definition__status quota_definition__last_allocation_date  \
# 0                   Closed                             28/01/2021
# 1                   Closed                                    NaN
#
#    quota_definition__initial_volume  quota_definition__balance  \
# 0                           2022900              2022900.00000
# 1                           2112000              2112000.00000
#
#    quota_definition__fill_rate
# 0                      0.00000
# 1                      0.00000

# %%
#df["quota__commodities"] = df["quota__commodities"].str.replace("|","") # remove | and replace with nothing
#df["quota__commodities"] = df["quota__commodities"].str.replace("|",";") # remove | and replace with ";"
df["quota__commodities"] = df["quota__commodities"].str.replace("|"," , ") # remove | and replace with " , "
df.head(3)
# Out:
# <ipython-input-14-718f22263530>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["quota__commodities"] = df["quota__commodities"].str.replace("|"," , ") # remove | and replace with " , "
#    quota_definition__sid quota__order_number quota__geographical_areas  \
# 0                  20815               50006                ERGA OMNES
# 1                  20814               50006                ERGA OMNES
# 2                  21865               50006                ERGA OMNES
#
#                                      quota__headings  \
# 0  0302 – Fish, fresh or chilled, excluding fish ...
# 1  0302 – Fish, fresh or chilled, excluding fish ...
# 2  0302 – Fish, fresh or chilled, excluding fish ...
#
#                                   quota__commodities quota__measurement_unit  \
# 0  0302410000 , 0303510000 , 0304595000 , 0304599...           Kilogram (kg)
# 1  0302410000 , 0303510000 , 0304595000 , 0304599...           Kilogram (kg)
# 2  0302410000 , 0303510000 , 0304595000 , 0304599...           Kilogram (kg)
#
#    quota__monetary_unit  quota_definition__description  \
# 0                   NaN                            NaN
# 1                   NaN                            NaN
# 2                   NaN                            NaN
#
#   quota_definition__validity_start_date quota_definition__validity_end_date  \
# 0                            01/01/2021                          14/02/2021
# 1                            16/06/2021                          14/02/2022
# 2                            16/06/2022                          14/02/2023
#
#   quota_definition__suspension_periods  quota_definition__blocking_periods  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
#
#   quota_definition__status quota_definition__last_allocation_date  \
# 0                   Closed                             28/01/2021
# 1                   Closed                                    NaN
# 2                   Future                                    NaN
#
#    quota_definition__initial_volume  quota_definition__balance  \
# 0                           2022900              2022900.00000
# 1                           2112000              2112000.00000
# 2                           2112000                        NaN
#
#    quota_definition__fill_rate
# 0                      0.00000
# 1                      0.00000
# 2                      0.00000

# %%
# remvoe "0" from string and convert to numeric
df = trade.head(20).copy()
df["commodity_code"] = df["commodity_code"].str.replace("0","").astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               20 non-null     int64
#  1   flow               20 non-null     object
#  2   commodity_code     20 non-null     int64
#  3   country_code       20 non-null     object
#  4   country_name       20 non-null     object
#  5   value_gbp          20 non-null     int64
#  6   suppression_notes  0 non-null      float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.2+ KB

# %%
# remove strings form multiple columns:
# pre-define columns and apply function to columns
# remove "T" from country columns
df = trade.copy()
df.head()
# Out:
#    year     flow commodity_code country_code country_name  value_gbp  \
# 0  2020  Exports       01012100           TW       Taiwan        892
# 1  2020  Exports       01062000           TW       Taiwan      14101
# 2  2020  Exports       01063100           TW       Taiwan       1750
# 3  2020  Exports       02031913           TW       Taiwan     290818
# 4  2020  Exports       02031990           TW       Taiwan       1140
#
#    suppression_notes
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
df = trade.copy()
df[["country_code","country_name"]] = df[["country_code","country_name"]].replace('T','*', regex=True)
df.head()
# Out:
#    year     flow commodity_code country_code country_name  value_gbp  \
# 0  2020  Exports       01012100           *W       *aiwan        892
# 1  2020  Exports       01062000           *W       *aiwan      14101
# 2  2020  Exports       01063100           *W       *aiwan       1750
# 3  2020  Exports       02031913           *W       *aiwan     290818
# 4  2020  Exports       02031990           *W       *aiwan       1140
#
#    suppression_notes
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# #### remove whitespace

# %%
df = uk_trqs.copy()
df["quota__commodities"] = df["quota__commodities"].str.replace("|"," , ") 
df["quota__commodities"] = df["quota__commodities"].str.strip() # remvoe whitespace across entire string
df["quota__commodities"] = df["quota__commodities"].str.lstrip() # remove whitespace from left handside of string
df["quota__commodities"] = df["quota__commodities"].str.rstrip() # remove whitespace from righthand side of string
df.head()
# Out:
# <ipython-input-22-75fdb58124e0>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["quota__commodities"] = df["quota__commodities"].str.replace("|"," , ")
#    quota_definition__sid quota__order_number quota__geographical_areas  \
# 0                  20815               50006                ERGA OMNES
# 1                  20814               50006                ERGA OMNES
# 2                  21865               50006                ERGA OMNES
# 3                  20816               50007                ERGA OMNES
# 4                  21866               50007                ERGA OMNES
#
#                                      quota__headings  \
# 0  0302 – Fish, fresh or chilled, excluding fish ...
# 1  0302 – Fish, fresh or chilled, excluding fish ...
# 2  0302 – Fish, fresh or chilled, excluding fish ...
# 3                                            0305 –
# 4                                            0305 –
#
#                                   quota__commodities quota__measurement_unit  \
# 0  0302410000 , 0303510000 , 0304595000 , 0304599...           Kilogram (kg)
# 1  0302410000 , 0303510000 , 0304595000 , 0304599...           Kilogram (kg)
# 2  0302410000 , 0303510000 , 0304595000 , 0304599...           Kilogram (kg)
# 3  0305511010 , 0305511020 , 0305519010 , 0305519...           Kilogram (kg)
# 4  0305511010 , 0305511020 , 0305519010 , 0305519...           Kilogram (kg)
#
#    quota__monetary_unit  quota_definition__description  \
# 0                   NaN                            NaN
# 1                   NaN                            NaN
# 2                   NaN                            NaN
# 3                   NaN                            NaN
# 4                   NaN                            NaN
#
#   quota_definition__validity_start_date quota_definition__validity_end_date  \
# 0                            01/01/2021                          14/02/2021
# 1                            16/06/2021                          14/02/2022
# 2                            16/06/2022                          14/02/2023
# 3                            01/01/2021                          31/12/2021
# 4                            01/01/2022                          31/12/2022
#
#   quota_definition__suspension_periods  quota_definition__blocking_periods  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
#
#   quota_definition__status quota_definition__last_allocation_date  \
# 0                   Closed                             28/01/2021
# 1                   Closed                                    NaN
# 2                   Future                                    NaN
# 3                   Closed                             30/12/2021
# 4                 Critical                             28/02/2022
#
#    quota_definition__initial_volume  quota_definition__balance  \
# 0                           2022900              2022900.00000
# 1                           2112000              2112000.00000
# 2                           2112000                        NaN
# 3                              2000                 5093.10000
# 4                              2000                  106.69600
#
#    quota_definition__fill_rate
# 0                      0.00000
# 1                      0.00000
# 2                      0.00000
# 3                      0.00000
# 4                      0.94665

# %% [markdown]
# ### 3. String detection

# %%
# check string contain pattern to create new columns or filter data

# create flags if the quota unit in the uk_trqs dataset contian KG, Litre, Hectolitre etc. 
df = uk_trqs.copy()
df["kg_flag"] = df["quota__measurement_unit"].str.contains("(kg)")
df["hl_flag"] = df["quota__measurement_unit"].str.contains("hl")
df.head()
#df.loc[df["hl_flag"]==True]
# the default output is True/False.
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/strings/accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#    quota_definition__sid quota__order_number quota__geographical_areas  \
# 0                  20815               50006                ERGA OMNES
# 1                  20814               50006                ERGA OMNES
# 2                  21865               50006                ERGA OMNES
# 3                  20816               50007                ERGA OMNES
# 4                  21866               50007                ERGA OMNES
#
#                                      quota__headings  \
# 0  0302 – Fish, fresh or chilled, excluding fish ...
# 1  0302 – Fish, fresh or chilled, excluding fish ...
# 2  0302 – Fish, fresh or chilled, excluding fish ...
# 3                                            0305 –
# 4                                            0305 –
#
#                                   quota__commodities quota__measurement_unit  \
# 0  0302410000|0303510000|0304595000|0304599010|03...           Kilogram (kg)
# 1  0302410000|0303510000|0304595000|0304599010|03...           Kilogram (kg)
# 2  0302410000|0303510000|0304595000|0304599010|03...           Kilogram (kg)
# 3  0305511010|0305511020|0305519010|0305519020|03...           Kilogram (kg)
# 4  0305511010|0305511020|0305519010|0305519020|03...           Kilogram (kg)
#
#    quota__monetary_unit  quota_definition__description  \
# 0                   NaN                            NaN
# 1                   NaN                            NaN
# 2                   NaN                            NaN
# 3                   NaN                            NaN
# 4                   NaN                            NaN
#
#   quota_definition__validity_start_date quota_definition__validity_end_date  \
# 0                            01/01/2021                          14/02/2021
# 1                            16/06/2021                          14/02/2022
# 2                            16/06/2022                          14/02/2023
# 3                            01/01/2021                          31/12/2021
# 4                            01/01/2022                          31/12/2022
#
#   quota_definition__suspension_periods  quota_definition__blocking_periods  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
#
#   quota_definition__status quota_definition__last_allocation_date  \
# 0                   Closed                             28/01/2021
# 1                   Closed                                    NaN
# 2                   Future                                    NaN
# 3                   Closed                             30/12/2021
# 4                 Critical                             28/02/2022
#
#    quota_definition__initial_volume  quota_definition__balance  \
# 0                           2022900              2022900.00000
# 1                           2112000              2112000.00000
# 2                           2112000                        NaN
# 3                              2000                 5093.10000
# 4                              2000                  106.69600
#
#    quota_definition__fill_rate  kg_flag  hl_flag
# 0                      0.00000     True    False
# 1                      0.00000     True    False
# 2                      0.00000     True    False
# 3                      0.00000     True    False
# 4                      0.94665     True    False

# %%
# you can easily create custom columns using np.where logic if you don't
df = uk_trqs.copy()
df["kg_flag"] = np.where(df["quota__measurement_unit"].str.contains("kg"),"Yes","No")
df.head(3)
# Out:
#    quota_definition__sid quota__order_number quota__geographical_areas  \
# 0                  20815               50006                ERGA OMNES
# 1                  20814               50006                ERGA OMNES
# 2                  21865               50006                ERGA OMNES
#
#                                      quota__headings  \
# 0  0302 – Fish, fresh or chilled, excluding fish ...
# 1  0302 – Fish, fresh or chilled, excluding fish ...
# 2  0302 – Fish, fresh or chilled, excluding fish ...
#
#                                   quota__commodities quota__measurement_unit  \
# 0  0302410000|0303510000|0304595000|0304599010|03...           Kilogram (kg)
# 1  0302410000|0303510000|0304595000|0304599010|03...           Kilogram (kg)
# 2  0302410000|0303510000|0304595000|0304599010|03...           Kilogram (kg)
#
#    quota__monetary_unit  quota_definition__description  \
# 0                   NaN                            NaN
# 1                   NaN                            NaN
# 2                   NaN                            NaN
#
#   quota_definition__validity_start_date quota_definition__validity_end_date  \
# 0                            01/01/2021                          14/02/2021
# 1                            16/06/2021                          14/02/2022
# 2                            16/06/2022                          14/02/2023
#
#   quota_definition__suspension_periods  quota_definition__blocking_periods  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
#
#   quota_definition__status quota_definition__last_allocation_date  \
# 0                   Closed                             28/01/2021
# 1                   Closed                                    NaN
# 2                   Future                                    NaN
#
#    quota_definition__initial_volume  quota_definition__balance  \
# 0                           2022900              2022900.00000
# 1                           2112000              2112000.00000
# 2                           2112000                        NaN
#
#    quota_definition__fill_rate kg_flag
# 0                      0.00000     Yes
# 1                      0.00000     Yes
# 2                      0.00000     Yes

# %%
# filter data using pattern match
# filter df where quota heading contains "fish"
df = uk_trqs.copy()
df_filt = df.loc[df["quota__headings"].str.contains("Fish")]
df_filt
# Out:
#       quota_definition__sid quota__order_number quota__geographical_areas  \
# 0                     20815               50006                ERGA OMNES
# 1                     20814               50006                ERGA OMNES
# 2                     21865               50006                ERGA OMNES
# 5                     20817               50008                ERGA OMNES
# 6                     21867               50008                ERGA OMNES
# ...                     ...                 ...                       ...
# 2395                  22105               58304                    Canada
# 2396                  22106               58304                    Canada
# 2573                  20762               58403                    Canada
# 2574                  22103               58403                    Canada
# 2575                  22104               58403                    Canada
#
#                                         quota__headings  \
# 0     0302 – Fish, fresh or chilled, excluding fish ...
# 1     0302 – Fish, fresh or chilled, excluding fish ...
# 2     0302 – Fish, fresh or chilled, excluding fish ...
# 5     0302 – Fish, fresh or chilled, excluding fish ...
# 6     0302 – Fish, fresh or chilled, excluding fish ...
# ...                                                 ...
# 2395  0304 – Fish fillets and other fish meat (wheth...
# 2396  0304 – Fish fillets and other fish meat (wheth...
# 2573  0304 – Fish fillets and other fish meat (wheth...
# 2574  0304 – Fish fillets and other fish meat (wheth...
# 2575  0304 – Fish fillets and other fish meat (wheth...
#
#                                      quota__commodities  \
# 0     0302410000|0303510000|0304595000|0304599010|03...
# 1     0302410000|0303510000|0304595000|0304599010|03...
# 2     0302410000|0303510000|0304595000|0304599010|03...
# 5     0302311000|0302321000|0302331000|0302341000|03...
# 6     0302311000|0302321000|0302331000|0302341000|03...
# ...                                                 ...
# 2395                                          304839019
# 2396                                          304839019
# 2573                              0304719000|0304791000
# 2574                              0304719000|0304791000
# 2575                              0304719000|0304791000
#
#      quota__measurement_unit  quota__monetary_unit  \
# 0              Kilogram (kg)                   NaN
# 1              Kilogram (kg)                   NaN
# 2              Kilogram (kg)                   NaN
# 5              Kilogram (kg)                   NaN
# 6              Kilogram (kg)                   NaN
# ...                      ...                   ...
# 2395        Tonne (1,000 kg)                   NaN
# 2396        Tonne (1,000 kg)                   NaN
# 2573           Kilogram (kg)                   NaN
# 2574           Kilogram (kg)                   NaN
# 2575           Kilogram (kg)                   NaN
#
#       quota_definition__description quota_definition__validity_start_date  \
# 0                               NaN                            01/01/2021
# 1                               NaN                            16/06/2021
# 2                               NaN                            16/06/2022
# 5                               NaN                            01/01/2021
# 6                               NaN                            01/01/2022
# ...                             ...                                   ...
# 2395                            NaN                            01/01/2022
# 2396                            NaN                            01/01/2023
# 2573                            NaN                            01/01/2021
# 2574                            NaN                            01/01/2022
# 2575                            NaN                            01/01/2023
#
#      quota_definition__validity_end_date quota_definition__suspension_periods  \
# 0                             14/02/2021                                  NaN
# 1                             14/02/2022                                  NaN
# 2                             14/02/2023                                  NaN
# 5                             31/12/2021                                  NaN
# 6                             31/12/2022                                  NaN
# ...                                  ...                                  ...
# 2395                          31/12/2022                                  NaN
# 2396                          31/12/2023                                  NaN
# 2573                          31/12/2021                                  NaN
# 2574                          31/12/2022                                  NaN
# 2575                          31/12/2023                                  NaN
#
#       quota_definition__blocking_periods quota_definition__status  \
# 0                                    NaN                   Closed
# 1                                    NaN                   Closed
# 2                                    NaN                   Future
# 5                                    NaN                   Closed
# 6                                    NaN                     Open
# ...                                  ...                      ...
# 2395                                 NaN                     Open
# 2396                                 NaN                   Future
# 2573                                 NaN                   Closed
# 2574                                 NaN                     Open
# 2575                                 NaN                   Future
#
#      quota_definition__last_allocation_date  quota_definition__initial_volume  \
# 0                                28/01/2021                           2022900
# 1                                       NaN                           2112000
# 2                                       NaN                           2112000
# 5                                       NaN                             29000
# 6                                       NaN                             29000
# ...                                     ...                               ...
# 2395                                    NaN                                10
# 2396                                    NaN                                10
# 2573                             08/12/2021                            791000
# 2574                             18/03/2022                            791000
# 2575                                    NaN                            791000
#
#       quota_definition__balance  quota_definition__fill_rate
# 0                 2022900.00000                      0.00000
# 1                 2112000.00000                      0.00000
# 2                           NaN                      0.00000
# 5                   29000.00000                      0.00000
# 6                   29000.00000                      0.00000
# ...                         ...                          ...
# 2395                   10.00000                      0.00000
# 2396                        NaN                      0.00000
# 2573               186732.00000                      0.76393
# 2574               726460.00000                      0.08159
# 2575                        NaN                      0.00000
#
# [103 rows x 17 columns]

# %%
# filter data where fish does not exisit in column:
df = uk_trqs.copy()
df_filt = df.loc[~(df["quota__headings"].str.contains("Fish"))]
df_filt
# Out:
#       quota_definition__sid quota__order_number quota__geographical_areas  \
# 3                     20816               50007                ERGA OMNES
# 4                     21866               50007                ERGA OMNES
# 9                     20819               50013                ERGA OMNES
# 10                    21869               50013                ERGA OMNES
# 11                    20820               50023                ERGA OMNES
# ...                     ...                 ...                       ...
# 2843                  22025               59281                    Canada
# 2844                  22026               59281                    Canada
# 2845                  20768               59282                    Canada
# 2846                  22033               59282                    Canada
# 2847                  22034               59282                    Canada
#
#                                         quota__headings  \
# 3                                               0305 –
# 4                                               0305 –
# 9     4412 – Plywood, veneered panels and similar la...
# 10    4412 – Plywood, veneered panels and similar la...
# 11                                  7202 – Ferro-alloys
# ...                                                 ...
# 2843  0202 – Meat of bovine animals, frozen|0206 – E...
# 2844  0202 – Meat of bovine animals, frozen|0206 – E...
# 2845  0203 – Meat of swine, fresh, chilled or frozen...
# 2846  0203 – Meat of swine, fresh, chilled or frozen...
# 2847  0203 – Meat of swine, fresh, chilled or frozen...
#
#                                      quota__commodities  \
# 3     0305511010|0305511020|0305519010|0305519020|03...
# 4     0305511010|0305511020|0305519010|0305519020|03...
# 9     4412390010|4412419900|4412419910|4412490000|44...
# 10    4412390010|4412419900|4412419910|4412490000|44...
# 11                                7202491020|7202495011
# ...                                                 ...
# 2843  0202100015|0202100099|0202201015|0202201099|02...
# 2844  0202100015|0202100099|0202201015|0202201099|02...
# 2845  0203121100|0203121900|0203191100|0203191300|02...
# 2846  0203121100|0203121900|0203191100|0203191300|02...
# 2847  0203121100|0203121900|0203191100|0203191300|02...
#
#      quota__measurement_unit  quota__monetary_unit  \
# 3              Kilogram (kg)                   NaN
# 4              Kilogram (kg)                   NaN
# 9           Cubic meter (m3)                   NaN
# 10          Cubic meter (m3)                   NaN
# 11             Kilogram (kg)                   NaN
# ...                      ...                   ...
# 2843           Kilogram (kg)                   NaN
# 2844           Kilogram (kg)                   NaN
# 2845           Kilogram (kg)                   NaN
# 2846           Kilogram (kg)                   NaN
# 2847           Kilogram (kg)                   NaN
#
#       quota_definition__description quota_definition__validity_start_date  \
# 3                               NaN                            01/01/2021
# 4                               NaN                            01/01/2022
# 9                               NaN                            01/01/2021
# 10                              NaN                            01/01/2022
# 11                              NaN                            01/01/2021
# ...                             ...                                   ...
# 2843                            NaN                            01/01/2022
# 2844                            NaN                            01/01/2023
# 2845                            NaN                            01/01/2021
# 2846                            NaN                            01/01/2022
# 2847                            NaN                            01/01/2023
#
#      quota_definition__validity_end_date quota_definition__suspension_periods  \
# 3                             31/12/2021                                  NaN
# 4                             31/12/2022                                  NaN
# 9                             31/12/2021                                  NaN
# 10                            31/12/2022                                  NaN
# 11                            31/12/2021                                  NaN
# ...                                  ...                                  ...
# 2843                          31/12/2022                                  NaN
# 2844                          31/12/2023                                  NaN
# 2845                          31/12/2021                                  NaN
# 2846                          31/12/2022                                  NaN
# 2847                          31/12/2023                                  NaN
#
#       quota_definition__blocking_periods quota_definition__status  \
# 3                                    NaN                   Closed
# 4                                    NaN                 Critical
# 9                                    NaN                Exhausted
# 10                                   NaN                 Critical
# 11                                   NaN                   Closed
# ...                                  ...                      ...
# 2843                                 NaN                     Open
# 2844                                 NaN                   Future
# 2845                                 NaN                   Closed
# 2846                                 NaN                 Critical
# 2847                                 NaN                   Future
#
#      quota_definition__last_allocation_date  quota_definition__initial_volume  \
# 3                                30/12/2021                              2000
# 4                                28/02/2022                              2000
# 9                                17/05/2021                            167352
# 10                               22/03/2022                            167352
# 11                                      NaN                            146000
# ...                                     ...                               ...
# 2843                             18/02/2022                            968000
# 2844                                    NaN                            968000
# 2845                                    NaN                           4838000
# 2846                             14/03/2022                           4838000
# 2847                                    NaN                           4838000
#
#       quota_definition__balance  quota_definition__fill_rate
# 3                    5093.10000                      0.00000
# 4                     106.69600                      0.94665
# 9                       0.00000                      1.00000
# 10                  49782.16200                      0.70253
# 11                 146000.00000                      0.00000
# ...                         ...                          ...
# 2843               951585.94000                      0.01696
# 2844                        NaN                      0.00000
# 2845              4838000.00000                      0.00000
# 2846                 5805.00000                      0.99880
# 2847                        NaN                      0.00000
#
# [2745 rows x 17 columns]

# %%
# filter using str.contains with regex:
df = uk_trqs.copy()
df_filt = df.loc[df["quota__headings"].str.contains("eggs")]
df_filt2 = df.loc[df["quota__headings"].str.contains("Fish")]
print(df_filt.shape,df_filt2.shape)
# Out:
# (117, 17) (103, 17)

# %% [markdown]
# two dataframes contain 117 and 103 rows respectively. When combined we would expect a 220 row df.

# %%
# combining the or "|" operator wuthin str.contians enables a wider pattern recognition. 
df_filt = df.loc[df["quota__headings"].str.contains("Fish|eggs")]
df_filt
# Out:
#       quota_definition__sid quota__order_number  \
# 0                     20815               50006
# 1                     20814               50006
# 2                     21865               50006
# 5                     20817               50008
# 6                     21867               50008
# ...                     ...                 ...
# 2823                  22459               59161
# 2824                  22460               59161
# 2825                  21050               59162
# 2826                  22491               59162
# 2827                  22492               59162
#
#                     quota__geographical_areas  \
# 0                                  ERGA OMNES
# 1                                  ERGA OMNES
# 2                                  ERGA OMNES
# 5                                  ERGA OMNES
# 6                                  ERGA OMNES
# ...                                       ...
# 2823  Ceuta|European Union|Melilla|San Marino
# 2824  Ceuta|European Union|Melilla|San Marino
# 2825  Ceuta|European Union|Melilla|San Marino
# 2826  Ceuta|European Union|Melilla|San Marino
# 2827  Ceuta|European Union|Melilla|San Marino
#
#                                         quota__headings  \
# 0     0302 – Fish, fresh or chilled, excluding fish ...
# 1     0302 – Fish, fresh or chilled, excluding fish ...
# 2     0302 – Fish, fresh or chilled, excluding fish ...
# 5     0302 – Fish, fresh or chilled, excluding fish ...
# 6     0302 – Fish, fresh or chilled, excluding fish ...
# ...                                                 ...
# 2823  1604 – Prepared or preserved fish; caviar and ...
# 2824  1604 – Prepared or preserved fish; caviar and ...
# 2825  1604 – Prepared or preserved fish; caviar and ...
# 2826  1604 – Prepared or preserved fish; caviar and ...
# 2827  1604 – Prepared or preserved fish; caviar and ...
#
#                                      quota__commodities  \
# 0     0302410000|0303510000|0304595000|0304599010|03...
# 1     0302410000|0303510000|0304595000|0304599010|03...
# 2     0302410000|0303510000|0304595000|0304599010|03...
# 5     0302311000|0302321000|0302331000|0302341000|03...
# 6     0302311000|0302321000|0302331000|0302341000|03...
# ...                                                 ...
# 2823                                         1604140000
# 2824                                         1604140000
# 2825                                         1604207000
# 2826                                         1604207000
# 2827                                         1604207000
#
#      quota__measurement_unit  quota__monetary_unit  \
# 0              Kilogram (kg)                   NaN
# 1              Kilogram (kg)                   NaN
# 2              Kilogram (kg)                   NaN
# 5              Kilogram (kg)                   NaN
# 6              Kilogram (kg)                   NaN
# ...                      ...                   ...
# 2823        Tonne (1,000 kg)                   NaN
# 2824        Tonne (1,000 kg)                   NaN
# 2825        Tonne (1,000 kg)                   NaN
# 2826        Tonne (1,000 kg)                   NaN
# 2827        Tonne (1,000 kg)                   NaN
#
#       quota_definition__description quota_definition__validity_start_date  \
# 0                               NaN                            01/01/2021
# 1                               NaN                            16/06/2021
# 2                               NaN                            16/06/2022
# 5                               NaN                            01/01/2021
# 6                               NaN                            01/01/2022
# ...                             ...                                   ...
# 2823                            NaN                            01/01/2022
# 2824                            NaN                            01/01/2023
# 2825                            NaN                            01/01/2021
# 2826                            NaN                            01/01/2022
# 2827                            NaN                            01/01/2023
#
#      quota_definition__validity_end_date quota_definition__suspension_periods  \
# 0                             14/02/2021                                  NaN
# 1                             14/02/2022                                  NaN
# 2                             14/02/2023                                  NaN
# 5                             31/12/2021                                  NaN
# 6                             31/12/2022                                  NaN
# ...                                  ...                                  ...
# 2823                          31/12/2022                                  NaN
# 2824                          31/12/2023                                  NaN
# 2825                          31/12/2021                                  NaN
# 2826                          31/12/2022                                  NaN
# 2827                          31/12/2023                                  NaN
#
#       quota_definition__blocking_periods quota_definition__status  \
# 0                                    NaN                   Closed
# 1                                    NaN                   Closed
# 2                                    NaN                   Future
# 5                                    NaN                   Closed
# 6                                    NaN                     Open
# ...                                  ...                      ...
# 2823                                 NaN                     Open
# 2824                                 NaN                   Future
# 2825                                 NaN                   Closed
# 2826                                 NaN                     Open
# 2827                                 NaN                   Future
#
#      quota_definition__last_allocation_date  quota_definition__initial_volume  \
# 0                                28/01/2021                           2022900
# 1                                       NaN                           2112000
# 2                                       NaN                           2112000
# 5                                       NaN                             29000
# 6                                       NaN                             29000
# ...                                     ...                               ...
# 2823                             11/03/2022                              3000
# 2824                                    NaN                              3000
# 2825                                    NaN                              4000
# 2826                             28/02/2022                              4000
# 2827                                    NaN                              4000
#
#       quota_definition__balance  quota_definition__fill_rate
# 0                 2022900.00000                      0.00000
# 1                 2112000.00000                      0.00000
# 2                           NaN                      0.00000
# 5                   29000.00000                      0.00000
# 6                   29000.00000                      0.00000
# ...                         ...                          ...
# 2823              2999437.15300                      0.00000
# 2824                        NaN                      0.00000
# 2825                 4000.00000                      0.00000
# 2826              3999999.86800                      0.00000
# 2827                        NaN                      0.00000
#
# [220 rows x 17 columns]

# %% [markdown]
# ### Glossary

# %% [markdown]
# #### 1. String manipulaiton

# %% [markdown]
# ```python
#
# # combine strings
#
# string3 = string1+string2
# df["new_col"] = df["col1"] + "_" + df["col2"] + "end_string"
#
# # map using integer
#
# df["new_col"] = df["value_col"].map(str) + df["string_col"]
# ```

# %% [markdown]
# ```python
# # extract strings
#
# # LEFT
# # first 4 strings
# df["left"] = df["col1"].str.slice(0,4) # index 0 is first string.
# # alternatively:
# df["left"] = df["col1"].[:4]
#
# # RIGHT
# # last 4 strings (8 digit string)
# df["right"] = df["col1"].str.slice(5,8) # start on 5th string, 6, 7 and end at 8.
# df["right"] = df["col1"].str[-4:]
#
# # MID
# # middle 4 strings (8 digit string)
# df["mid"] = df["col1"].str.slice(2,6)
#
#
# ```

# %% [markdown]
# ```python
# # string lengths
#
# df["length"] = df["col1"].str.len() # only if column is character string
# df["length"] = df["col1"].map(str).apply(len) # use map(str) + apply(len) if checking string length of numerical column
# ```

# %% [markdown]
# ### 2. String removal

# %% [markdown]
# #### patterns

# %% [markdown]
# ```python
# # string replace
# df["col"].str.replace("pattern","pattern_replace")
# df["col"].str.replace(";",",") # etc.
#
# # replace string from multiple df columns:
#
# cols = ["col1","col2","col3"]
#
# df["cols"] = df["cols"].replace("string_to_remove","string_to_replace", regex = True)
#
# # whitespace
#
# df["col"].str.strip() # remove whitesapce in entire cell
# df["col"].str.lstrip() # remove whitespace from left of cell
# df["col"].str.rstrip() # remove whitespace form right of cell
#
# ```

# %% [markdown]
# ### 3. String detection

# %% [markdown]
# ```python
# # detect string:
#
# df["col"].str.contains("pattern")
#
# # create column using pattern and non True/False output.
#
# df["new_col"] = np.where(df["col"].str.contains("pattern"),"pattern_exists","pattern_doesn't_exist")
#
# # filter data based on pattern
#
# df_filt = df.loc[df["col"].str.contains("pattern")]
#
# # doesn't contain pattern:
#
# df_filt = df.loc[~(df["col"].str.contains("pattern"))]
#
# # combine with regex for multiple conditions:
#
# df_filt = df.loc[df["col"].str.contains("pattern1|pattern2")
#
# ```

# %% [markdown]
# End.
